# %% [markdown]
# # Assignment on preprocessing

# %% [markdown]
# ### 1. Load the dataset into python environment

# %%
# import necessary libraries

import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'/content/titanic_dataset.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 2. Make ‘PassengerId’ as the index column

# %%
data = pd.read_csv(r'/content/titanic_dataset.csv', index_col = 'PassengerId')

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### 3. Check the basic details of the dataset

# %%
data.shape
# Out:
# (891, 11)

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ### 4. Fill in all the missing values present in all the columns in the dataset

# %%
# FFilling missing values for the 'Age' column with mean value
data['Age'].fillna(data['Age'].mean(), inplace=True)

# %%
# Filling missing values for the 'Cabin' column
data['Cabin'].fillna('Unknown', inplace=True)

# %%
# Filling missing values for the 'Embarked' column with the mode
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### 5. Check and handle outliers in at least 3 columns in the dataset

# %%
import seaborn as sns

# %%
# utliers in Age column
sns.boxplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# Outliers in Fare column
sns.boxplot(data['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
# Outliers SibSp column
sns.boxplot(data['SibSp'])
# Out:
# <Axes: ylabel='SibSp'>

# %% [markdown]
# ### Identify and handle outliers in Age column

# %%
age_threshold = 10

# %%
# Identifying outliers
age_outlier = data[data['Age'] < age_threshold]

# %%
age_outlier
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 8                   0       3            Palsson, Master. Gosta Leonard
# 11                  1       3           Sandstrom, Miss. Marguerite Rut
# 17                  0       3                      Rice, Master. Eugene
# 25                  0       3             Palsson, Miss. Torborg Danira
# 44                  1       2  Laroche, Miss. Simonne Marie Anne Andree
# ...               ...     ...                                       ...
# 828                 1       2                     Mallet, Master. Andre
# 832                 1       2           Richards, Master. George Sibley
# 851                 0       3   Andersson, Master. Sigvard Harald Elias
# 853                 0       3                   Boulos, Miss. Nourelain
# 870                 1       3           Johnson, Master. Harold Theodor
#
#                 Sex   Age  SibSp  Parch           Ticket     Fare    Cabin  \
# ...

# %% [markdown]
# ### Identify and handle outliers in SibSp column

# %%
sibsp_threshold = 5

# %%
# Identifying outliers
sibsp_outlier = data[data['SibSp'] > sibsp_threshold]

# %%
sibsp_outlier
# Out:
#              Survived  Pclass                               Name     Sex  \
# PassengerId
# 160                 0       3         Sage, Master. Thomas Henry    male
# 181                 0       3       Sage, Miss. Constance Gladys  female
# 202                 0       3                Sage, Mr. Frederick    male
# 325                 0       3           Sage, Mr. George John Jr    male
# 793                 0       3            Sage, Miss. Stella Anna  female
# 847                 0       3           Sage, Mr. Douglas Bullen    male
# 864                 0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#                    Age  SibSp  Parch    Ticket   Fare    Cabin Embarked
# PassengerId
# 160          29.699118      8      2  CA. 2343  69.55  Unknown        S
# 181          29.699118      8      2  CA. 2343  69.55  Unknown        S
# 202          29.699118      8      2  CA. 2343  69.55  Unknown        S
# ...

# %%
sibsp_outlier.shape
# Out:
# (7, 11)

# %% [markdown]
# ### Identify and handle outliers in Fare column

# %%
fare_threshold = 10

# %%
# Identifying outliers
fare_outlier = data[data['Fare'] > fare_threshold]

# %%
fare_outlier
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 8                   0       3
# 9                   1       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
#
#                                                           Name     Sex  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 7                                      McCarthy, Mr. Timothy J    male
# 8                               Palsson, Master. Gosta Leonard    male
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# ...                                                        ...     ...
# ...

# %% [markdown]
# ### 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Drop irrelevant columns
data = data.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)

# %%
data = data.dropna()

# %%
data
# Out:
#              Survived  Pclass        Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.000000      1      0   7.2500
# 2                   1       1  38.000000      1      0  71.2833
# 3                   1       3  26.000000      0      0   7.9250
# 4                   1       1  35.000000      1      0  53.1000
# 5                   0       3  35.000000      0      0   8.0500
# ...               ...     ...        ...    ...    ...      ...
# 887                 0       2  27.000000      0      0  13.0000
# 888                 1       1  19.000000      0      0  30.0000
# 889                 0       3  29.699118      1      2  23.4500
# 890                 1       1  26.000000      0      0  30.0000
# 891                 0       3  32.000000      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
data = data.drop('Survived', axis=1)

# %%
scaler = MinMaxScaler()

# %%
scaled_features = scaler.fit_transform(data)

# %%
scaled_features
# Out:
# array([[1.        , 0.27117366, 0.125     , 0.        , 0.01415106],
#        [0.        , 0.4722292 , 0.125     , 0.        , 0.13913574],
#        [1.        , 0.32143755, 0.        , 0.        , 0.01546857],
#        ...,
#        [1.        , 0.36792055, 0.125     , 0.33333333, 0.04577135],
#        [0.        , 0.32143755, 0.        , 0.        , 0.0585561 ],
#        [1.        , 0.39683338, 0.        , 0.        , 0.01512699]])

# %%
sns.boxplot(scaled_features)
# Out:
# <Axes: >

# %%
data
# Out:
#              Pclass        Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  22.000000      1      0   7.2500
# 2                 1  38.000000      1      0  71.2833
# 3                 3  26.000000      0      0   7.9250
# 4                 1  35.000000      1      0  53.1000
# 5                 3  35.000000      0      0   8.0500
# ...             ...        ...    ...    ...      ...
# 887               2  27.000000      0      0  13.0000
# 888               1  19.000000      0      0  30.0000
# 889               3  29.699118      1      2  23.4500
# 890               1  26.000000      0      0  30.0000
# 891               3  32.000000      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
data.shape
# Out:
# (891, 5)

# %%
data.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
data.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   13.002015    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      3.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Age     891 non-null    float64
#  2   SibSp   891 non-null    int64
#  3   Parch   891 non-null    int64
#  4   Fare    891 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 41.8 KB

# %%
data.isna().sum()
# Out:
# Pclass    0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64
